# %% [markdown]
# # Eksperymenty Minimax vs Random
# Symulacje gier Minimax przeciwko losowemu graczowi w celu porównania jakości algorytmu dla różnych głębokości przeszukiwania.

# %%
from minimax_evaluation import simulate_games

# %% [markdown]
# ### Test algorytmu Minimax z głębokością 2

# %%
depth = 2
nb_of_games = 100
wins, draws, losses = simulate_games(depth, nb_of_games, ai_player='x')

print(f"Minimax - depth {depth} (x) vs Random (o) - 100 games:")
print(f"Wins (x):   {wins}")
print(f"Draws (x):  {draws}")
print(f"Losses (x): {losses}")
# Out:
# Minimax - depth 2 (x) vs Random (o) - 100 games:
# Wins (x):   89
# Draws (x):  3
# Losses (x): 8

# %% [markdown]
# ### Test algorytmu Minimax z głębokością 3

# %%
depth = 3
nb_of_games = 100
wins, draws, losses = simulate_games(depth, nb_of_games, ai_player='x')

print(f"Minimax - depth {depth} (x) vs Random (o) - 100 games:")
print(f"Wins (x):   {wins}")
print(f"Draws (x):  {draws}")
print(f"Losses (x): {losses}")
# Out:
# Minimax - depth 3 (x) vs Random (o) - 100 games:
# Wins (x):   92
# Draws (x):  1
# Losses (x): 7

# %% [markdown]
# ### Test algorytmu Minimax z głębokością 4

# %%
depth = 4
nb_of_games = 100
wins, draws, losses = simulate_games(depth, nb_of_games, ai_player='x')

print(f"Minimax - depth {depth} (x) vs Random (o) - 100 games:")
print(f"Wins (x):   {wins}")
print(f"Draws (x):  {draws}")
print(f"Losses (x): {losses}")
# Out:
# Minimax - depth 4 (x) vs Random (o) - 100 games:
# Wins (x):   96
# Draws (x):  0
# Losses (x): 4
